# %% [markdown]
# # Exercise 1 : Token count by word length
# *** Import GPT 4 tokenizer and the time machine text ***
# - split words by whitespaces and punctuations(including punctuations as "words")
